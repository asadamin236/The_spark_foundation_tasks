# %% [markdown]
# ## Task No 2: DATA SCIENCE AND BUSINESS ANALYTICS INTERN (THE SPARKS FOUNDATION)
#
# By Asad Amin

# %% [markdown]
# ## Task:
# From the given iris dataset we have to find out optimum number of clusters and represent it visually.

# %% [markdown]
# ## Dataset link for the given task:
# https://bit.ly/3kXTdox

# %% [markdown]
# ## Tools used for this project:

# %% [markdown]
# Language used for this task: Python
#
# IDE (Integrated Development Environment) used for this project: Jupyter notebook

# %% [markdown]
# ## Import required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans 
# %matplotlib inline

# %% [markdown]
# ## Import dataset

# %%
Df = pd.read_csv('Iris.csv')

# %%
Df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## Data preprocessing and cleaning

# %%
# Check shape of the data.
Df.shape
# Out:
# (150, 6)

# %%
# Check information of the data
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Check statistics for data.
Df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Check for null values.
Df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Count the values of the species
Df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Data visualization (EDA) part of the project.

# %%
# Count species on countplot.
sns.countplot(Df['Species'])
# Out:
# C:\Users\ASAD\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
# Create relplot for the given data sepallenggth and sepalwidth. 
sns.relplot(x=Df['SepalLengthCm'], y=Df['SepalWidthCm'])

# %%
# Create pairplot for all the dataset.
sns.pairplot(Df)

# %%
# Create the boxplot for the sepallenggth and sepalwidth columns. 
plt.rcParams['figure.figsize']=(15, 5)
sns.boxplot(x=Df['SepalLengthCm'], y=Df['SepalWidthCm'])
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# ## Drop the two columns id and species.

# %%
X=Df.drop(['Id','Species'], axis=1)

# %%
X.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
X.shape
# Out:
# (150, 4)

# %% [markdown]
# ## Apply the kmeans clustering on the dataset

# %%
plt.rcParams['figure.figsize']=(10, 5)
wcss = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    km.fit(X)
    wcss.append(km.inertia_)
    
#plot the results
plt.plot(range(1, 11), wcss)
plt.title('The ELbo Chart', fontsize=15)
plt.xlabel('No of clusters')
plt.ylabel('wcss')
plt.show()
# Out:
# C:\Users\ASAD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1038: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# Fitting our dataset with Kmeans clustring model with 3 number of clusters because our greater point on 3.

kmeans = KMeans(n_clusters=3, init='k-means++', random_state=0)
Y = kmeans.fit_predict(X)
X=X.values

# Predicting clusters of the dataset and visualize on scatterlot. 

plt.figure(figsize=(15,8))
plt.scatter(X[Y==0, 0], X[Y==0, 1], s =20, c ='red', label='Iris-setosa')
plt.scatter(X[Y==1, 0], X[Y==1, 1], s =20, c ='green', label='Iris-versicolor')
plt.scatter(X[Y==2, 0], X[Y==2, 1], s =20, c ='blue', label='Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
           s=100, c='yellow', label="Centroids")
plt.legend()
plt.show()
